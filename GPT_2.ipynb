# %% [markdown]
# <a href="https://colab.research.google.com/github/lamlun2012/Python_prtc.-CDD-TT/blob/main/GPT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

from transformers import GPT2Tokenizer, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %%
pip install pdfplumber

# %%
import pdfplumber

text = ""
with pdfplumber.open("Python rat la co ban - Vo Duy Tuan.pdf") as pdf:
    for page in pdf.pages:
        text += page.extract_text() + "\n"

with open("train.txt", "w", encoding="utf-8") as f:
    f.write(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4139528541.py in <cell line: 0>()
#       2
#       3 text = ""
# ----> 4 with pdfplumber.open("Python rat la co ban - Vo Duy Tuan.pdf") as pdf:
#       5     for page in pdf.pages:
#       6         text += page.extract_text() + "\n"
#
# /usr/local/lib/python3.12/dist-packages/pdfplumber/pdf.py in open(cls, path_or_fp, pages, laparams, password, strict_metadata, unicode_norm, repair, gs_path, repair_setting, raise_unicode_errors)
#      96             path = None
#      97         elif isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 98             stream = open(path_or_fp, "rb")
#      99             stream_is_external = False
#     100             path = pathlib.Path(path_or_fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Python rat la co ban - Vo Duy Tuan.pdf'
